# %%
import os
for root, dirs, files in os.walk("."):
    print(root)
# Out:
# .
# ./tcx
# ./json
# ./.ipynb_checkpoints

# %%
pwd
# Out:
# '/Users/bryan/DU_Data_Analytics_BC/GitHub/project_visualization/Digital-Workout-Tracker/data'

# %%
ls -al
# Out:
# total 896
# drwxr-xr-x   13 bryan  staff     416 Oct 16 17:01 ./
# drwxr-xr-x   13 bryan  staff     416 Oct 16 15:43 ../
# drwxr-xr-x    4 bryan  staff     128 Oct 16 16:57 .ipynb_checkpoints/
# -rw-r--r--@   1 bryan  staff  313032 Oct 13 19:53 Activities.csv
# -rw-r--r--    1 bryan  staff   30765 Oct 16 15:43 Untitled.ipynb
# -rw-r--r--    1 bryan  staff    1831 Oct 16 17:01 Untitled1.ipynb
# -rw-r--r--@   1 bryan  staff    1157 Oct 16 15:43 copy_text.py
# -rw-r--r--@   1 bryan  staff       0 Oct 10 12:10 data_readme.txt
# -rw-r--r--@   1 bryan  staff     118 Oct 16 15:43 garmin_parse.py
# drwxr-xr-x    4 bryan  staff     128 Oct 16 15:43 json/
# -rw-r--r--    1 bryan  staff   94148 Oct 16 15:54 npActivityTracker.ipynb
# drwxr-xr-x  663 bryan  staff   21216 Oct 16 15:43 tcx/
# -rw-r--r--@   1 bryan  staff     454 Oct 13 19:53 userstats.json

# %%
for root, dirs, files in os.walk("."):
    print(dirs)
# Out:
# ['tcx', 'json', '.ipynb_checkpoints']
# []
# []
# []

# %%
for root, dirs, files in os.walk("."):
    for file in files:
        print(file)
# Out:
# copy_text.py
# garmin_parse.py
# Untitled1.ipynb
# npActivityTracker.ipynb
# Untitled.ipynb
# Activities.csv
# userstats.json
# data_readme.txt
# activity_1926552470_Glenwood_Springs_Cyc.tcx
# activity_944695274_Glenwood_Springs_Cyc.tcx
# activity_3642981298_Mesa_County_Hiking.tcx
# activity_3545473354_07162014_Glenwood_Sp.tcx
# activity_1139050821_Glenwood_Springs_Cyc.tcx
# activity_3598234_easy_run.tcx
# activity_1985467026_Glenwood_Springs_Cyc.tcx
# activity_1188286704_Carbondale_Hiking.tcx
# activity_594231832_.tcx
# activity_7991715_.tcx
# activity_819599524_.tcx
# activity_5374973372_Colorado_Springs_Run.tcx
# activity_3652102156_Indoor_Cycling.tcx
# activity_3657358956_Treadmill_Running.tcx
# activity_7991742_.tcx
# activity_3275047844_Indoor_Cycling.tcx
# activity_7990796_.tcx
# activity_819599532_.tcx
# activity_778307974_Glenwood_Springs_Cyc.tcx
# activity_5577339972.tcx
# activity_3229311613_Mesa_County_Snowboar.tcx
# activity_510821584_.tcx
# activity_819599420_.tcx
# ...
